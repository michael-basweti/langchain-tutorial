# %% [markdown]
# # **Messages**

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

from dotenv import load_dotenv
import os
load_dotenv()


if os.environ['GEMINI_API_KEY']:
    print('gemini key set')
else:
    print("not set")
# Out:
# gemini key set

# %% [markdown]
# ## **Initialize LLM**

# %%
# Initialize the Gemini model
llm = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

my_messages = [
    HumanMessage(content="How are you?"),
    SystemMessage(content="You're a gen-z assistant who answers in a fun playful way")
]

llm.invoke(my_messages).content[0]["text"]
# Out:
# "I'm doing great, thank you for asking! How are you doing today? Is there anything I can help you with?"

# %% [markdown]
# ## **Prompts**
#
# prompts are more user friendly than messages

# %%
from langchain_core.prompts import PromptTemplate

user_input = input("Enter topic about fact")

dynamic_prompt = PromptTemplate.from_template("write a fun fact about: {topic}")

# ready_prompt = dynamic_prompt.invoke({"topic":user_input})

chain = dynamic_prompt | llm

chain.invoke({"topic":user_input}).content[0]["text"]
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# 'A fun fact about thorns is that they are actually **modified branches or stems.**\n\nWhile many people use the word "thorn" to describe any sharp plant part, botanists are very specific:\n\n*   **Thorns** are modified branches (they have a vascular connection to the plant\'s main stem).\n*   **Spines** are modified leaves (like those on a cactus).\n*   **Prickles** are extensions of the plant\'s outer "skin" or bark (like the sharp bits on a rose bush).\n\nBecause thorns are essentially "stunted" branches, if you try to snap one off, it often takes a piece of the woody stem with it, whereas prickles can usually be peeled off the surface of the stem quite easily!'

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system","you are a helpful assistant"),
    ("user","Write a fun fact about {topic}")
])

chain = prompt_template | llm

user_insert = input("Enter a topic to get fun fact")

chain.invoke({"topic":user_insert}).content[0]["text"]
# Out:
# 'Did you know that **sunflowers are actually "nature’s solar panels"**? \n\nYoung sunflowers exhibit a behavior called **heliotropism**: throughout the day, their buds track the movement of the sun across the sky from east to west. At night, they reset and face east again to prepare for the sunrise! Once they fully mature, they stop moving and usually stay facing east to help attract pollinators that prefer the warmth of the morning sun.'
